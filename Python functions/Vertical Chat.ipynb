# %% [markdown]
# # Vertical Chat
# A sample how to build a chat for small businees using:
#
# * GPT 35
# * Panel
# * OpenAI
#
# Create a .py file to be executed with Streamlt
# I'm using jupyter just to keep it simple
# feel free to use you favourite IDE like Pycharm or any other.

# %%
# !pip install openai
# !pip install panel
# Out:
# Collecting openai
#   Downloading openai-0.27.7-py3-none-any.whl (71 kB)
#                                               0.0/72.0 kB ? eta -:--:--
#      ---------------------------------------  71.7/72.0 kB 2.0 MB/s eta 0:00:01
#      ---------------------------------------- 72.0/72.0 kB 2.0 MB/s eta 0:00:00
# Collecting requests>=2.20 (from openai)
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting tqdm (from openai)
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# Collecting aiohttp (from openai)
#   Downloading aiohttp-3.8.4-cp311-cp311-win_amd64.whl (317 kB)
#                                               0.0/317.2 kB ? eta -:--:--
#      -------------------                    163.8/317.2 kB 5.0 MB/s eta 0:00:01
#      -------------------------------------- 317.2/317.2 kB 3.9 MB/s eta 0:00:00
# Collecting charset-normalizer<4,>=2 (from requests>=2.20->openai)
#   Using cached charset_normalizer-3.1.0-cp311-cp311-win_amd64.whl (96 kB)
# Collecting idna<4,>=2.5 (from requests>=2.20->openai)
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.20->openai)
#   Using cached urllib3-2.0.2-py3-none-any.whl (123 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.20->openai)
#   Using cached certifi-2023.5.7-py3-none-any.whl (156 kB)
# Collecting attrs>=17.3.0 (from aiohttp->openai)
#   Using cached attrs-23.1.0-py3-none-any.whl (61 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->openai)
#   Downloading multidict-6.0.4-cp311-cp311-win_amd64.whl (28 kB)
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->openai)
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->openai)
#   Downloading yarl-1.9.2-cp311-cp311-win_amd64.whl (60 kB)
#                                               0.0/60.2 kB ? eta -:--:--
#      ---------------------------------------- 60.2/60.2 kB ? eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->openai)
#   Downloading frozenlist-1.3.3-cp311-cp311-win_amd64.whl (32 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->openai)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: colorama in c:\users\rajag\desktop\hackathons\relive\.venv\lib\site-packages (from tqdm->openai) (0.4.6)
# Installing collected packages: urllib3, tqdm, multidict, idna, frozenlist, charset-normalizer, certifi, attrs, async-timeout, yarl, requests, aiosignal, aiohttp, openai
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 attrs-23.1.0 certifi-2023.5.7 charset-normalizer-3.1.0 frozenlist-1.3.3 idna-3.4 multidict-6.0.4 openai-0.27.7 requests-2.31.0 tqdm-4.65.0 urllib3-2.0.2 yarl-1.9.2
# Collecting panel
#   Downloading panel-1.0.3-py2.py3-none-any.whl (19.9 MB)
#                                               0.0/19.9 MB ? eta -:--:--
#                                              0.0/19.9 MB 991.0 kB/s eta 0:00:21
#                                               0.1/19.9 MB 1.7 MB/s eta 0:00:12
#                                               0.2/19.9 MB 1.6 MB/s eta 0:00:13
#                                               0.2/19.9 MB 1.5 MB/s eta 0:00:13
#                                               0.2/19.9 MB 1.5 MB/s eta 0:00:13
#                                              0.3/19.9 MB 923.9 kB/s eta 0:00:22
#                                               0.4/19.9 MB 1.1 MB/s eta 0:00:18
#      -                                        0.5/19.9 MB 1.5 MB/s eta 0:00:14
#      -                                        0.6/19.9 MB 1.4 MB/s eta 0:00:14
#      -                                        0.7/19.9 MB 1.5 MB/s eta 0:00:13
#      -                                        0.8/19.9 MB 1.5 MB/s eta 0:00:13
#      -                                        0.8/19.9 MB 1.4 MB/s eta 0:00:14
#      -                                        0.9/19.9 MB 1.5 MB/s eta 0:00:13
#      -                                        1.0/19.9 MB 1.5 MB/s eta 0:00:13
#      --                                       1.2/19.9 MB 1.7 MB/s eta 0:00:12
#      --                                       1.4/19.9 MB 1.8 MB/s eta 0:00:11
#      --                                       1.5/19.9 MB 1.9 MB/s eta 0:00:10
#      ---                                      1.8/19.9 MB 2.1 MB/s eta 0:00:09
#      ---                                      2.0/19.9 MB 2.2 MB/s eta 0:00:09
#      ----                                     2.2/19.9 MB 2.4 MB/s eta 0:00:08
#      ----                                     2.4/19.9 MB 2.5 MB/s eta 0:00:08
#      -----                                    2.7/19.9 MB 2.7 MB/s eta 0:00:07
#      ------                                   3.0/19.9 MB 2.8 MB/s eta 0:00:06
#      ------                                   3.3/19.9 MB 3.0 MB/s eta 0:00:06
#      ------                                   3
3 MB 6.7 MB/s eta 0:00:01
#      ---------------------------------        7.0/8.3 MB 6.7 MB/s eta 0:00:01
#      -----------------------------------      7.3/8.3 MB 6.7 MB/s eta 0:00:01
#      -------------------------------------    7.7/8.3 MB 6.8 MB/s eta 0:00:01
#      ---------------------------------------  8.1/8.3 MB 6.8 MB/s eta 0:00:01
#      ---------------------------------------  8.3/8.3 MB 6.7 MB/s eta 0:00:01
#      ---------------------------------------- 8.3/8.3 MB 6.5 MB/s eta 0:00:00
# Collecting param>=1.12.0 (from panel)
#   Downloading param-1.13.0-py2.py3-none-any.whl (87 kB)
#                                               0.0/87.3 kB ? eta -:--:--
#      ---------------------------------------- 87.3/87.3 kB 4.8 MB/s eta 0:00:00
# Collecting pyviz-comms>=0.7.4 (from panel)
#   Downloading pyviz_comms-2.3.0-py2.py3-none-any.whl (43 kB)
#                                               0.0/43.8 kB ? eta -:--:--
#      ---------------------------------------- 43.8/43.8 kB 2.1 MB/s eta 0:00:00
# Collecting xyzservices>=2021.09.1 (from panel)
#   Downloading xyzservices-2023.5.0-py3-none-any.whl (56 kB)
#                                               0.0/56.5 kB ? eta -:--:--
#      ---------------------------------------- 56.5/56.5 kB 3.1 MB/s eta 0:00:00
# Collecting markdown (from panel)
#   Downloading Markdown-3.4.3-py3-none-any.whl (93 kB)
#                                               0.0/93.9 kB ? eta -:--:--
#      ---------------------------------------- 93.9/93.9 kB 5.2 MB/s eta 0:00:00
# Collecting markdown-it-py (from panel)
#   Using cached markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
# Collecting linkify-it-py (from panel)
#   Downloading linkify_it_py-2.0.2-py3-none-any.whl (19 kB)
# Collecting mdit-py-plugins (from panel)
#   Downloading mdit_py_plugins-0.3.5-py3-none-any.whl (52 kB)
#                                               0.0/52.1 kB ? eta -:--:--
#      ---------------------------------------- 52.1/52.1 kB ? eta 0:00:00
# Requirement already satisfied: requests in c:\users\rajag\desktop\hackathons\relive\.venv\lib\site-packages (from panel) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\rajag\desktop\hackathons\relive\.venv\lib\site-packages (from panel) (4.65.0)
# Collecting bleach (from panel)
#   Using cached bleach-6.0.0-py3-none-any.whl (162 kB)
# Collecting typing-extensions (from panel)
#   Using cached typing_extensions-4.6.2-py3-none-any.whl (31 kB)
# Collecting pandas>=1.2 (from panel)
#   Downloading pandas-2.0.2-cp311-cp311-win_amd64.whl (10.6 MB)
#                                               0.0/10.6 MB ? eta -:--:--
#      -                                        0.3/10.6 MB 8.9 MB/s eta 0:00:02
#      --                                       0.7/10.6 MB 8.3 MB/s eta 0:00:02
#      ---                                      0.9/10.6 MB 7.2 MB/s eta 0:00:02
#      ----                                     1.2/10.6 MB 7.1 MB/s eta 0:00:02
#      ------                                   1.6/10.6 MB 7.3 MB/s eta 0:00:02
#      -------                                  1.9/10.6 MB 7.3 MB/s eta 0:00:02
#      --------                                 2.3/10.6 MB 7.3 MB/s eta 0:00:02
#      ---------                                2.6/10.6 MB 7.3 MB/s eta 0:00:02
#      -----------                              3.1/10.6 MB 7.5 MB/s eta 0:00:02
#      ------------                             3.4/10.6 MB 7.5 MB/s eta 0:00:01
#      --------------                           3.7/10.6 MB 7.5 MB/s eta 0:00:01
#      ---------------                          4.1/10.6 MB 7.5 MB/s eta 0:00:01
#      ----------------                         4.3/10.6 MB 7.6 MB/s eta 0:00:01
#      -----------------                        4.5/10.6 MB 7.1 MB/s eta 0:00:01
#      ------------------                       4.9/10.6 MB 7.1 MB/s eta 0:00:01
#      -------------------                      5.2/10.6 MB 7.1 MB/s eta 0:00:01
#      --------------------                     5.5/10.6 MB 7.2 MB/s eta 0:00:01
#      ----------------------                   5.9/10.6 MB 7.2 MB/s eta 0:00:01
#      ----------------------                   6.0/10.6 MB 7.0 MB/s eta 0:00:01
#      -----------------------                  6.1/10.6 MB 6.7 MB/s eta 0:00:01
#      ------------------------                 6.4/10.6 MB 6.7 MB/s eta 0:00:01
#      -------------------------                6.7/10.6 MB 6.7 MB/s eta 0:00:01
#      -------------------------                6.7/10.6 MB 6.7 MB/s eta 0:00:01
#      -------------------------                6.7/10.6 MB 6.7 MB/s eta 0:00:01
#      -------------------------                6.7/10.6 MB 6.7 MB/s eta 0:00:01
#      ----------------------------             7.5/10.6 MB 6.3 MB/s eta 0:00:01
#      -----------------------------            7.7/10.6 MB 6.2 MB/s eta 0:00:01
#      -----------------------------            7.8/10.6 MB 6.2 MB/s eta 0:00:01
#      -----------------------------            7.9/10.6 MB 6.0 MB/s eta 0:00:01
#      ------------------------------           8.0/10.6 MB 5.8 MB/s eta 0:00:01
#      ------------------------------           8.1/10.6 MB 5.8 MB/s eta 0:00:01
#      ------------------------------           8.2/10.6 MB 5.6 MB/s eta 0:00:01
#      -------------------------------          8.3/10.6 MB 5.6 MB/s eta 0:00:01
#      --------------------------------         8.7/10.6 MB 5.5 MB/s eta 0:00:01
#      ---------------------------------        8.9/10.6 MB 5.5 MB/s eta 0:00:01
#      ----------------------------------       9.1/10.6 MB 5.5 MB/s eta 0:00:01
#      ----------------------------------       9.2/10.6 MB 5.5 MB/s eta 0:00:01
#      -----------------------------------      9.3/10.6 MB 5.3 MB/s eta 0:00:01
#      ------------------------------------     9.6/10.6 MB 5.4 MB/s eta 0:00:01
#      ------------------------------------     9.7/10.6 MB 5.3 MB/s eta 0:00:01
#      --------------------------------------   10.1/10.6 MB 5.3 MB/s eta 0:00:01
#      --------------------------------------   10.3/10.6 MB 5.3 MB/s eta 0:00:01
#      ---------------------------------------  10.6/10.6 MB 5.3 MB/s eta 0:00:01
#      ---------------------------------------- 10.6/10.6 MB 5.2 MB/s eta 0:00:00
# Collecting Jinja2>=2.9 (from bokeh<3.2.0,>=3.1.1->panel)
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting contourpy>=1 (from bokeh<3.2.0,>=3.1.1->panel)
#   Downloading contourpy-1.0.7-cp311-cp311-win_amd64.whl (162 kB)
#                                               0.0/163.0 kB ? eta -:--:--
#      -------------------------------------- 163.0/163.0 kB 4.9 MB/s eta 0:00:00
# Collecting numpy>=1.16 (from bokeh<3.2.0,>=3.1.1->panel)
#   Using cached numpy-1.24.3-cp311-cp311-win_amd64.whl (14.8 MB)
# Requirement already satisfied: packaging>=16.8 in c:\users\rajag\desktop\hackathons\relive\.venv\lib\site-packages (from bokeh<3.2.0,>=3.1.1->panel) (23.1)
# Collecting pillow>=7.1.0 (from bokeh<3.2.0,>=3.1.1->panel)
#   Using cached Pillow-9.5.0-cp311-cp311-win_amd64.whl (2.5 MB)
# Collecting PyYAML>=3.10 (from bokeh<3.2.0,>=3.1.1->panel)
#   Using cached PyYAML-6.0-cp311-cp311-win_amd64.whl (143 kB)
# Requirement already satisfied: tornado>=5.1 in c:\users\rajag\desktop\hackathons\relive\.venv\lib\site-packages (from bokeh<3.2.0,>=3.1.1->panel) (6.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rajag\desktop\hackathons\relive\.venv\lib\site-packages (from pandas>=1.2->panel) (2.8.2)
# Collecting pytz>=2020.1 (from pandas>=1.2->panel)
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# Collecting tzdata>=2022.1 (from pandas>=1.2->panel)
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Requirement already satisfied: colorama in c:\users\rajag\desktop\hackathons\relive\.venv\lib\site-packages (from tqdm>=4.48.0->panel) (0.4.6)
# Requirement already satisfied: six>=1.9.0 in c:\users\rajag\desktop\hackathons\relive\.venv\lib\site-packages (from bleach->panel) (1.16.0)
# Collecting webencodings (from bleach->panel)
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting uc-micro-py (from linkify-it-py->panel)
#   Downloading uc_micro_py-1.0.2-py3-none-any.whl (6.2 kB)
# Collecting mdurl~=0.1 (from markdown-it-py->panel)
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rajag\desktop\hackathons\relive\.venv\lib\site-packages (from requests->panel) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rajag\desktop\hackathons\relive\.venv\lib\site-packages (from requests->panel) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rajag\desktop\hackathons\relive\.venv\lib\site-packages (from requests->panel) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rajag\desktop\hackathons\relive\.venv\lib\site-packages (from requests->panel) (2023.5.7)
# Collecting MarkupSafe>=2.0 (from Jinja2>=2.9->bokeh<3.2.0,>=3.1.1->panel)
#   Using cached MarkupSafe-2.1.2-cp311-cp311-win_amd64.whl (16 kB)
# Installing collected packages: webencodings, pytz, xyzservices, uc-micro-py, tzdata, typing-extensions, PyYAML, pillow, param, numpy, mdurl, MarkupSafe, markdown, bleach, pyviz-comms, pandas, markdown-it-py, linkify-it-py, Jinja2, contourpy, mdit-py-plugins, bokeh, panel
# Successfully installed Jinja2-3.1.2 MarkupSafe-2.1.2 PyYAML-6.0 bleach-6.0.0 bokeh-3.1.1 contourpy-1.0.7 linkify-it-py-2.0.2 markdown-3.4.3 markdown-it-py-2.2.0 mdit-py-plugins-0.3.5 mdurl-0.1.2 numpy-1.24.3 pandas-2.0.2 panel-1.0.3 param-1.13.0 pillow-9.5.0 pytz-2023.3 pyviz-comms-2.3.0 typing-extensions-4.6.2 tzdata-2023.3 uc-micro-py-1.0.2 webencodings-0.5.1 xyzservices-2023.5.0

# %%
import openai 
import panel as pn
# from mykeys import openai_api_key
openai.api_key= "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"

# %%
def continue_conversation(messages, temperature=0):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=messages,
        temperature=temperature, 
    )
    #print(str(response.choices[0].message["content"]))
    return response.choices[0].message["content"]

# %%
def add_prompts_conversation(_):
    #Get the value introduced by the user
    prompt = client_prompt.value_input
    client_prompt.value = ''
    
    #Append to the context the User promnopt. 
    context.append({'role':'user', 'content':f"{prompt}"})
    
    #Get the response. 
    response = continue_conversation(context) 
    
    #Add the response to the context. 
    context.append({'role':'assistant', 'content':f"{response}"})
    
    #Undate the panels to shjow the conversation. 
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600, style={'background-color': '#F6F6F6'})))
 
    return pn.Column(*panels)

# %%
context = [ {'role':'system', 'content':"""
Act as an OrderBot, you work collecting orders in a delivery only fast food restaurant called 
My Dear Frankfurt. \
First welcome the customer, in a very friedly way, then collects the order. \
You wait to collect the entire order, beverages included \
then summarize it and check for a final \
time if everithing is ok or the customer wants to add anything else. \
Finally you collect the payment.\
Make sure to clarify all options, extras and sizes to uniquely \
identify the item from the menu.\
You respond in a short, very friendly style. \
The menu includes \
burguer  12.95, 10.00, 7.00 \
frankfurt   10.95, 9.25, 6.50 \
sandwich   11.95, 9.75, 6.75 \
fries 4.50, 3.50 \
salad 7.25 \
Toppings: \
extra cheese 2.00, \
mushrooms 1.50 \
martra sausage 3.00 \
canadian bacon 3.50 \
romesco sauce 1.50 \
peppers 1.00 \
Drinks: \
coke 3.00, 2.00, 1.00 \
sprite 3.00, 2.00, 1.00 \
vichy catalan 5.00 \
"""} ]  

#Creamos el panel. 
pn.extension()

panels = [] 

client_prompt = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="talk")

interactive_conversation = pn.bind(add_prompts_conversation, button_conversation)

dashboard = pn.Column(
    client_prompt,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True, height=300),
)

dashboard
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='bff71e2f-edef-48d0-93e8-b0d45d8bf059'>
#   <div id="fcccf597-7a04-45fb-899d-14a8f2cb6222" data-root-id="bff71e2f-edef-48d0-93e8-b0d45d8bf059" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"795e3936-0e7f-4515-aee1-ed9bdee502dd":{"version":"3.1.1","title":"Bokeh Application","defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}],"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"bff71e2f-edef-48d0-93e8-b0d45d8bf059"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"aeb069aa-32e3-4e5f-8a17-d02477aed99a","attributes":{"plot_id":"bff71e2f-edef-48d0-93e8-b0d45d8bf059","comm_id":"73f9959cbbcb499ab59ff753134d79e3","client_comm_id":"59eedad57428402fb5db2809a9c04c1b"}}],"callbacks":{"type":"map"}}};
#   var render_items = [{"docid":"795e3936-0e7f-4515-aee1-ed9bdee502dd","roots":{"bff71e2f-edef-48d0-93e8-b0d45d8bf059":"fcccf597-7a04-45fb-899d-14a8f2cb6222"},"root_ids":["bff71e2f-edef-48d0-93e8-b0d45d8bf059"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[5], line 44
#      37 button_conversation = pn.widgets.Button(name="talk")
#      39 interactive_conversation = pn.bind(add_prompts_conversation, button_conversation)
#      41 dashboard = pn.Column(
#      42     client_prompt,
#      43     pn.Row(button_conversation),
# ---> 44     pn.panel(interactive_conversation, loading_indicator=True, height=300),
#      45 )
#      47 dashboard
#
# File c:\Users\rajag\Desktop\hackathons\ReLive\.venv\Lib\site-packages\panel\pane\base.py:81, in panel(obj, **kwargs)
#      79 if kwargs.get('name', False) is None:
#      80     kwargs.pop('name')
# ---> 81 pane = PaneBase.get_pane_type(obj, **kwargs)(obj, **kwargs)
#      82 if len(pane.layout) == 1 and pane._unpack:
#      83     return pane.layout[0]
#
# File c:\Users\rajag\Desktop\hackathons\ReLive\.venv\Lib\site-packages\panel\param.py:778, in ParamMethod.__init__(self, object, **params)
#     776 self._validate_object()
#     777 if not self.defer_load:
# --> 778     self._replace_pane()
#
# File c:\Users\rajag\Desktop\hackathons\ReLive\.venv\Lib\site-packages\panel\param.py:823, in ParamMethod._replace_pane(self, force, *args)
#     821     new_object = Spacer()
#     822 else:
# --> 823     new_object = self.eval(self.object)
#     824 if inspect.isawaitable(new_object):
#     825     param.parameterized.async_executor(partial(self._eval_async, new_object))
#
# File c:\Users\rajag\Desktop\hackathons\ReLive\.venv\Lib\site-packages\panel\param.py:803, in ParamMethod.eval(self, function)
#     801 @classmethod
#     802 def eval(self, function):
# --> 803     return eval_function(function)
#
# File c:\Users\rajag\Desktop\hackathons\ReLive\.venv\Lib\site-packages\panel\util\__init__.py:325, in eval_function(function)
#     323         args = (getattr(dep.owner, dep.name) for dep in arg_deps)
#     324         kwargs = {n: getattr(dep.owner, dep.name) for n, dep in kw_deps.items()}
# --> 325 return function(*args, **kwargs)
#
# File c:\Users\rajag\Desktop\hackathons\ReLive\.venv\Lib\site-packages\param\parameterized.py:407, in depends.<locals>._depends(*args, **kw)
#     405 @wraps(func)
#     406 def _depends(*args, **kw):
# --> 407     return func(*args, **kw)
#
# File c:\Users\rajag\Desktop\hackathons\ReLive\.venv\Lib\site-packages\panel\depends.py:229, in _param_bind.<locals>.wrapped(*wargs, **wkwargs)
#     226 @depends(**dependencies, watch=watch)
#     227 def wrapped(*wargs, **wkwargs):
#     228     combined_args, combined_kwargs = combine_arguments(wargs, wkwargs)
# --> 229     return eval_fn()(*combined_args, **combined_kwargs)
#
# Cell In[4], line 10, in add_prompts_conversation(_)
#       7 context.append({'role':'user', 'content':f"{prompt}"})
#       9 #Get the response.
# ---> 10 response = continue_conversation(context)
#      12 #Add the response to the context.
#      13 context.append({'role':'assistant', 'content':f"{response}"})
#
# Cell In[3], line 2, in continue_conversation(messages, temperature)
#       1 def continue_conversation(messages, temperature=0):
# ----> 2     response = openai.ChatCompletion.create(
#       3         model="gpt-3.5-turbo",
#       4         messages=messages,
#       5         temperature=temperature,
#       6     )
#       7     #print(str(response.choices[0].message["content"]))
#       8     return response.choices[0].message["content"]
#
# File c:\Users\rajag\Desktop\hackathons\ReLive\.venv\Lib\site-packages\openai\api_resources\chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File c:\Users\rajag\Desktop\hackathons\ReLive\.venv\Lib\site-packages\openai\api_resources\abstract\engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File c:\Users\rajag\Desktop\hackathons\ReLive\.venv\Lib\site-packages\openai\api_requestor.py:230, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     209 def request(
#     210     self,
#     211     method,
#    (...)
#     218     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     219 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     220     result = self.request_raw(
#     221         method.lower(),
#     222         url,
#    (...)
#     228         request_timeout=request_timeout,
#     229     )
# --> 230     resp, got_stream = self._interpret_response(result, stream)
#     231     return resp, got_stream, self.api_key
#
# File c:\Users\rajag\Desktop\hackathons\ReLive\.venv\Lib\site-packages\openai\api_requestor.py:624, in APIRequestor._interpret_response(self, result, stream)
#     616     return (
#     617         self._interpret_response_line(
#     618             line, result.status_code, result.headers, stream=True
#     619         )
#     620         for line in parse_stream(result.iter_lines())
#     621     ), True
#     622 else:
#     623     return (
# --> 624         self._interpret_response_line(
#     625             result.content.decode("utf-8"),
#     626             result.status_code,
#     627             result.headers,
#     628             stream=False,
#     629         ),
#     630         False,
#     631     )
#
# File c:\Users\rajag\Desktop\hackathons\ReLive\.venv\Lib\site-packages\openai\api_requestor.py:687, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     685 stream_error = stream and "error" in resp.data
#     686 if stream_error or not 200 <= rcode < 300:
# --> 687     raise self.handle_error_response(
#     688         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     689     )
#     690 return resp
#
# RateLimitError: You exceeded your current quota, please check your plan and billing details.
